# %%
#!pip install -q matplotlib torch==1.2.0 torchtext==0.4.0 tensorboard future ipdb

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %reload_ext autoreload

# %%
#!pip install -q ipywidgets
#!jupyter nbextension enable --py widgetsnbextension

# %%
#!conda install -y -q -c conda-forge ipywidgets

# %%
import classify
from argparse import ArgumentParser

# %%
args, unknown = classify.get_arg_parser().parse_known_args()
args.e = 40
args.num_heads = 4
args.depth = 4
args.batch_size = 4
args.lr = 6e-4 #6e-4

# %%
from matplotlib import pyplot as plt

# %%
# %%time
#from IPython.core.debugger import set_trace
#set_trace()
classify.go(args)
# Out:
# - nr. of training examples 6250
# - nr. of test examples 6250
#
#  epoch 0
# ...
# instance in batch: 0
# label 0
# this is quite possibly the worst sequel ever made. the script is unfunny and the acting stinks. the exact opposite of the original.
# ..
# -- test accuracy 0.821
#
#  epoch 1
# ...
# instance in batch: 0
# label 0
# this is quite possibly the worst sequel ever made. the script is unfunny and the acting stinks. the exact opposite of the original.
# ..
# -- test accuracy 0.84
#
#  epoch 2
# ...
# instance in batch: 0
# label 0
# this is quite possibly the worst sequel ever made. the script is unfunny and the acting stinks. the exact opposite of the original.
# ..
# -- test accuracy 0.753
#
#  epoch 3
# ...
# instance in batch: 0
# label 0
# this is quite possibly the worst sequel ever made. the script is unfunny and the acting stinks. the exact opposite of the original.
# ..
# -- test accuracy 0.5
#
#  epoch 4
# ...

# %%
#STOP

# %%
import torch
t = torch.tensor([[ 1.,  2.,  3.], 
                  [ 1.,  1.,  1.],
                  [ 0., -1.,  1.]])

# %%
fig, ax = plt.subplots(4, 1)
img = ax[0].imshow(t)
plt.show(img)

# %%
ax.get_xticklabels()

# %%
ax.set_xticks(range(3))
ax.set_xticklabels(['A', 'B', 'C'])
ax.set_yticks(range(3))
ax.set_yticklabels(['A', 'B', 'C'])
ax.tick_params(axis='x', rotation=90)

# %%
plt.show()

# %%
plt.show(img)

# %%
display(img)

# %%
words = ['a', 'b']
[f'{w:20s}' for w in words]

# %%
fig = plt.figure(figsize=(16,4))
fig.tight_layout()
ax = fig.add_subplot(2, 3, 1)
ax.imshow(t)
# img = plt.imshow(t)
ax = fig.add_subplot(2, 3, 6)
ax.imshow(t*-1)

# img = plt.imshow(t*-1)
# ax = fig.add_subplot(2, 3, 3)
# img = plt.imshow(t*-3)
# ax = fig.add_subplot(2, 3, 4)
# img = plt.imshow(t)

#plt.show(fig)

# %%
#fig.tight_layout()
#plt.show(fig)
plt.show()

# %%
plt.tight_layout()
plt.show()
# FIXME: Show label as well
# FIXME: SHow sifferent example

# %%
4*['']
