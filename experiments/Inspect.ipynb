# %%
#!pip install -q matplotlib torch==1.2.0 torchtext==0.4.0 tensorboard future ipdb

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#!pip install -q ipywidgets
#!jupyter nbextension enable --py widgetsnbextension

# %%
#!conda install -y -q -c conda-forge ipywidgets

# %%
import classify
from argparse import ArgumentParser

# %%
args, unknown = classify.get_arg_parser().parse_known_args()
args.e = 6
args.num_heads = 4
args.depth = 4
args.batch_size = 4

# %%
from matplotlib import pyplot as plt

# %%
# %%time
#from IPython.core.debugger import set_trace
#set_trace()
classify.go(args)
# Out:
# - nr. of training examples 6250
# - nr. of test examples 6250
#
#  epoch 0
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6250.0), HTML(value='')))
# instance in batch: 0
# label 0
# hated it with all my being. worst movie ever. <unk> <unk> help me. it was that <unk> <unk>
# instance in batch: 1
# label 1
# absolutely fantastic! whatever i say wouldn't do this underrated movie the justice it deserves. watch it now! fantastic!
# instance in batch: 2
# label 1
# add this little gem to your list of holiday <unk> it is<br /><br <unk> funny, and endearing <pad>
# ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/code/former/experiments/classify.py in go(arg)
#     137                 if input.size(1) > mx:
#     138                     input = input[:, :mx]
# --> 139                 out, attentions = model(input)
#     140                 out = out.argmax(dim=1)
#     141                 if i == 2:
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/code/former/former/transformers.py in forward(self, x)
#      91         x = self.do(x)
#      92
# ---> 93         x, attentions = self.tblocks((x, []))
#      94         x = x.max(dim=1)[0] if self.max_pool else x.mean(dim=1) # pool over the time dimension
#      95
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/code/former/former/modules.py in forward(self, x)
#     176         x = self.do(x)
#     177
# --> 178         fedforward = self.ff(x)
#     179
#     180         x = self.norm2(fedforward + x)
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/modules/activation.py in forward(self, input)
#     100
#     101     def forward(self, input: Tensor) -> Tensor:
# --> 102         return F.relu(input, inplace=self.inplace)
#     103
#     104     def extra_repr(self) -> str:
#
# ~/Misc/anaconda3/envs/sm37/lib/python3.7/site-packages/torch/nn/functional.py in relu(input, inplace)
#    1117         result = torch.relu_(input)
#    1118     else:
# -> 1119         result = torch.relu(input)
#    1120     return result
#    1121
#
# KeyboardInterrupt:

# %%
#STOP

# %%
import torch
t = torch.tensor([[ 1.,  2.,  3.], 
                  [ 1.,  1.,  1.],
                  [ 0., -1.,  1.]])

# %%
fig, ax = plt.subplots(4, 1)
img = ax[0].imshow(t)
plt.show(img)

# %%
ax.get_xticklabels()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-863a9279edb1> in <module>
# ----> 1 ax.get_xticklabels()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_xticklabels'

# %%
ax.set_xticks(range(3))
ax.set_xticklabels(['A', 'B', 'C'])
ax.set_yticks(range(3))
ax.set_yticklabels(['A', 'B', 'C'])
ax.tick_params(axis='x', rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-9540f16de727> in <module>
# ----> 1 ax.set_xticks(range(3))
#       2 ax.set_xticklabels(['A', 'B', 'C'])
#       3 ax.set_yticks(range(3))
#       4 ax.set_yticklabels(['A', 'B', 'C'])
#       5 ax.tick_params(axis='x', rotation=90)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_xticks'

# %%
plt.show()

# %%
plt.show(img)

# %%
display(img)

# %%
words = ['a', 'b']
[f'{w:20s}' for w in words]
# Out:
# ['a                   ', 'b                   ']

# %%
fig = plt.figure(figsize=(16,4))
fig.tight_layout()
ax = fig.add_subplot(2, 3, 1)
ax.imshow(t)
# img = plt.imshow(t)
ax = fig.add_subplot(2, 3, 6)
ax.imshow(t*-1)

# img = plt.imshow(t*-1)
# ax = fig.add_subplot(2, 3, 3)
# img = plt.imshow(t*-3)
# ax = fig.add_subplot(2, 3, 4)
# img = plt.imshow(t)

#plt.show(fig)

# %%
#fig.tight_layout()
#plt.show(fig)
plt.show()

# %%
plt.tight_layout()
plt.show()
# FIXME: Show label as well
# FIXME: SHow sifferent example

# %%
4*['']
# Out:
# ['', '', '', '']
